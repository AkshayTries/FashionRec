# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshayTries/FashionRec-FC63/blob/main/ARt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cr00z/virtual-tryon
# !cp -r virtual-tryon/* .
# Out:
# Cloning into 'virtual-tryon'...
# remote: Enumerating objects: 113, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 113 (delta 50), reused 83 (delta 23), pack-reused 0
# Receiving objects: 100% (113/113), 11.29 MiB | 47.59 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-eanzxy2p
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-eanzxy2p
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 2c6c380f94a27bd8455a39506c9105f652b9f760
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !sudo apt-get --yes install libglu1-mesa-dev freeglut3-dev mesa-common-dev
# !sudo apt-get --yes install libosmesa6-dev
# !pip install opendr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libglu1-mesa-dev is already the newest version (9.0.1-1build1).
# libglu1-mesa-dev set to manually installed.
# The following additional packages will be installed:
#   freeglut3 libdrm-dev libpciaccess-dev
# The following NEW packages will be installed:
#   freeglut3 freeglut3-dev libdrm-dev libpciaccess-dev mesa-common-dev
# 0 upgraded, 5 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,853 kB of archives.
# After this operation, 4,065 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libpciaccess-dev amd64 0.16-0ubuntu1 [20.3 kB]
# ...

# %%
# %%time
pip -v install "git+https://github.com/facebookresearch/pytorch3d.git"
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git to /tmp/pip-req-build-6pi4zj4e
#   Running command git version
#   git version 2.25.1
#   Running command git clone --filter=blob:none https://github.com/facebookresearch/pytorch3d.git /tmp/pip-req-build-6pi4zj4e
#   Cloning into '/tmp/pip-req-build-6pi4zj4e'...
#   Updating files:   0% (2/1056)
#   Updating files:   1% (11/1056)
#   Updating files:   2% (22/1056)
#   Updating files:   3% (32/1056)
#   Updating files:   4% (43/1056)
#   Updating files:   5% (53/1056)
#   Updating files:   6% (64/1056)
#   Updating files:   7% (74/1056)
#   Updating files:   8% (85/1056)
#   Updating files:   9% (96/1056)
#   Updating files:  10% (106/1056)
#   Updating files:  11% (117/1056)
#   Updating files:  12% (127/1056)
# ...

# %%
# !sudo apt-get --yes install libboost-dev
# !pip install 'git+https://github.com/MPI-IS/mesh.git'
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-dev is already the newest version (1.71.0.0ubuntu2).
# libboost-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/MPI-IS/mesh.git to /tmp/pip-req-build-ekw3t6ha
#   Running command git clone --filter=blob:none --quiet https://github.com/MPI-IS/mesh.git /tmp/pip-req-build-ekw3t6ha
#   Resolved https://github.com/MPI-IS/mesh.git to commit 49e70425cf373ec5269917012bda2944215c5ccd
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for psbody-mesh: filename=psbody_mesh-0.4-cp310-cp310-linux_x86_64.whl size=2371705 sha256=f9525c6887bab89d17833bdbd3edf6a46d8e24f28e354b8ec51fd663551d4be9
# ...

# %%
# !echo "Download the neutral SMPL model"
# !wget https://github.com/classner/up/raw/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl -P assets

# !echo "Downloading extra data from SPIN"
# !wget http://visiondata.cis.upenn.edu/spin/data.tar.gz && tar -xvf data.tar.gz && rm data.tar.gz && mv data/smpl_mean_params.npz assets && rm -rf data

# !echo "Downloading pretrained model"
# !wget https://dl.fbaipublicfiles.com/eft/2020_05_31-00_50_43-best-51.749683916568756.pt -P assets

# !echo "Download garment fts from MultiGarmentNetwork"
# !wget https://github.com/bharat-b7/MultiGarmentNetwork/raw/master/assets/garment_fts.pkl -P assets
# Out:
# Download the neutral SMPL model
# --2023-05-18 20:17:04--  https://github.com/classner/up/raw/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl [following]
# --2023-05-18 20:17:04--  https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39001280 (37M) [application/octet-stream]
# Saving to: ‘assets/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’
#
# ...

# %%
# !wget https://datasets.d2.mpi-inf.mpg.de/MultiGarmentNetwork/Multi-Garmentdataset.zip
# !unzip Multi-Garmentdataset.zip
# Out:
# --2023-05-18 20:17:33--  https://datasets.d2.mpi-inf.mpg.de/MultiGarmentNetwork/Multi-Garmentdataset.zip
# Resolving datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)... 139.19.206.177
# Connecting to datasets.d2.mpi-inf.mpg.de (datasets.d2.mpi-inf.mpg.de)|139.19.206.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1084637022 (1.0G) [application/zip]
# Saving to: ‘Multi-Garmentdataset.zip’
#
# Multi-Garmentdatase 100%[===================>]   1.01G  30.1MB/s    in 43s
#
# 2023-05-18 20:18:16 (24.2 MB/s) - ‘Multi-Garmentdataset.zip’ saved [1084637022/1084637022]
#
# Archive:  Multi-Garmentdataset.zip
#    creating: Multi-Garment_dataset/
#    creating: Multi-Garment_dataset/125611512607128/
#   inflating: Multi-Garment_dataset/125611512607128/scan_labels.npy
#   inflating: Multi-Garment_dataset/125611512607128/scan.obj
#   inflating: Multi-Garment_dataset/125611512607128/smpl_registered.obj
# ...

# %%
input_path = './sample_data/single_totalbody.mp4'

# %%
# !python main.py
# Out:
# Video: ./trial1.mp4
# Frames total: 95
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Processing:   0% 0/95 [00:00<?, ?it/s]Figure(1000x500)
# Processing:   1% 1/95 [01:28<2:18:40, 88.51s/it]Figure(1000x500)
# Processing:   2% 2/95 [02:56<2:16:58, 88.37s/it]Figure(1000x500)
# Processing:   3% 3/95 [04:28<2:17:15, 89.51s/it]
# Generating video in out.mp4
# ...
